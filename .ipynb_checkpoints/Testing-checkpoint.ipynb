# %%
# import dependencies
import pandas as pd

# %%
# import the recipe data
# Dataset has full columns for Original Gravity (OG), Final Gravity (FG), ABV, IBU, and Color
recipe_data = pd.read_csv('./Data/recipeData.csv', encoding='latin-1')
recipe_data.head()

# import the style data
style_data = pd.read_csv('./Data/styleData.csv', encoding='latin-1')
style_data['Style'] = style_data['Style'].str.lower()
# style_data.head()

# %%
# replace N/A in number columns with 0, word columns with Unknown
num_cols = ['BoilGravity', 'Efficiency', 'MashThickness', 'PitchRate']
word_cols = ['PrimaryTemp', 'PrimingMethod', 'PrimingAmount']

recipe_data[num_cols]=recipe_data[num_cols].fillna(0)
recipe_data[word_cols]= recipe_data[word_cols].fillna("Unknown")

recipe_data.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# ...

# %%
# take in user input for a style name, use style_data to get the ID
user_style = input("What style of beer would you like to make? ")
user_style.lower()

# print(user_style)

# cycle through style to get the matching ID
def style_id_check(user_style):
    for index, row in style_data.iterrows():
        if row['Style'] == user_style:
            style_id = row['StyleID']
            break
        else:
            style_id = 0
    if style_id == 0:
        print("I'm sorry, that style cannot be found")
        user_style = input("Please enter another style: ")
        style_id_check(user_style)
    
    return style_id

style_id = style_id_check(user_style)
print("The style is: %s, the StyleID is %s" % (user_style, style_id))
# Out:
# What style of beer would you like to make? dafsj;f
# I'm sorry, that style cannot be found
# Please enter another style: altbier
# 1
# The style is: dafsj;f, the StyleID is 0

# %%
# trim columns for training of the model, remove Name, URL, Style,OG, FG, ABV, IBU, Color, UserId
recipe_data = recipe_data.drop(['Name', 'URL', 'Style', 'OG', 'FG', 'ABV', 'IBU', 'Color', 'UserId'], axis=1)
recipe_data.head()
# Out:
#    BeerID  StyleID  Size(L)  BoilSize  BoilTime  BoilGravity  Efficiency  \
# 0       1       45    21.77     28.39        75        1.038        70.0
# 1       2       85    20.82     24.61        60        1.070        70.0
# 2       3        7    18.93     22.71        60        0.000        70.0
# 3       4        7    22.71     26.50        60        0.000        70.0
# 4       5       20    50.00     60.00        90        1.050        72.0
#
#    MashThickness        SugarScale BrewMethod  PitchRate PrimaryTemp  \
# 0            0.0  Specific Gravity  All Grain        0.0       17.78
# 1            0.0  Specific Gravity  All Grain        0.0     Unknown
# 2            0.0  Specific Gravity    extract        0.0     Unknown
# 3            0.0  Specific Gravity  All Grain        0.0     Unknown
# 4            0.0  Specific Gravity  All Grain        0.0          19
#
#   PrimingMethod   PrimingAmount
# 0    corn sugar          4.5 oz
# 1       Unknown         Unknown
# ...

# %%
# use encoding to translate SugarScale, Brew Method, PrimingMethod, Priming Amount
# Out:
#                     Style  StyleID
# 0                 altbier        1
# 1  alternative grain beer        2
# 2  alternative sugar beer        3
# 3      american amber ale        4
# 4     american barleywine        5
